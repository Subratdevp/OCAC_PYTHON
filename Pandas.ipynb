# %% [markdown]
# ### Import Libraries

# %%
# Import numpy
import numpy as np

# %%
# Importing Pandas libaray
import pandas as pd

# %% [markdown]
# ### Create Pandas Series --> pandas.series

# %%
d = {'a': 1, 'b': 2, 'c': 3}
ser = pd.Series(data=d)
ser
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
d = {'a': 1, 'b': 2, 'c': 3}
ser = pd.Series(data=d, index=['a', 'y', 'c'])
ser
# Out:
# a    1.0
# y    NaN
# c    3.0
# dtype: float64

# %%
l=['banana', 42]
s = pd.Series(data=l)
print(s)
# Out:
# 0    banana
# 1        42
# dtype: object

# %%
s = pd.Series(['banana', 42], index=['a','b'])
print(s)
# Out:
# a    banana
# b        42
# dtype: object

# %%
s = pd.Series(['Wes Mckinney', 'Creator of Pandas'],index=['Person','who'])
print(s)
# Out:
# Person         Wes Mckinney
# who       Creator of Pandas
# dtype: object

# %%
# Creating a list of prices.
pricelist=[100,200,300,400]

#Creating a series.
productseries=pd.Series(pricelist)

#Displaying the Series.
print(productseries)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %% [markdown]
# ### Create data Frame --> pandas.DataFrame

# %%
# Constructing a DataFrame from a Dictionary
d = {'col1': [1,2], 'col2': [3,4]}
df = pd.DataFrame(data=d)
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Constructing a DataFrame from a Dictionary
scientists = pd.DataFrame({
'Name': ['Rosaline Franklin','William Gosset'],
'Occupation':['Chemist','Statistician'],
'Born': ['1920-07-25','1876-06-13'],
'Died': ['1920-04-16','1937-10-16'],
'Age': [37, 61]})

#Displaying the data frame
print(scientists)
# Out:
#                 Name    Occupation        Born        Died  Age
# 0  Rosaline Franklin       Chemist  1920-07-25  1920-04-16   37
# 1     William Gosset  Statistician  1876-06-13  1937-10-16   61

# %%
# Creating DataFrame using a List
productdf = pd.DataFrame([[100,200,300,400], [3,4,2,5]], columns = ['Pen', 'Shirt','Book','Mouse'])

#Displaying the Dataframe.
print(productdf)
# Out:
#    Pen  Shirt  Book  Mouse
# 0  100    200   300    400
# 1    3      4     2      5

# %% [markdown]
# ### Attributes

# %%
#Displaying the dimensions of the data frame using shape.
productdf.shape
# Out:
# (2, 4)

# %%
#Displaying the size of the data frame using size.
productdf.size
# Out:
# 8

# %%
#Displaying the name of the columns using keys () Function.
productdf.keys()
# Out:
# Index(['Pen', 'Shirt', 'Book', 'Mouse'], dtype='object')

# %%
productdf.columns
# Out:
# Index(['Pen', 'Shirt', 'Book', 'Mouse'], dtype='object')

# %% [markdown]
# ### Adding Column

# %%
#adding column named "Mobile" to the data frame.
productdf["Mobile"] = [15000, 2]
productdf
# Out:
#    Pen  Shirt  Book  Mouse  Mobile
# 0  100    200   300    400   15000
# 1    3      4     2      5       2

# %% [markdown]
# ##### Drop columns from the data frame
# ##### . Drop (Need to specify that axis = 0 or 'index', axis=1 or 'columns')

# %%
#Deleting multiple columns from the dataframe using drop() function.
df2 = productdf.drop("Mobile",axis=1)
df2
# Out:
#    Pen  Shirt  Book  Mouse
# 0  100    200   300    400
# 1    3      4     2      5

# %%
#Deleteing multiple columns from the data frame using drop() function.
df2 = productdf.drop(columns= ["Book"])
df2
# Out:
#    Pen  Shirt  Mouse  Mobile
# 0  100    200    400   15000
# 1    3      4      5       2

# %%
df2 = productdf.drop(columns= ["Mobile","Book"])
df2
# Out:
#    Pen  Shirt  Mouse
# 0  100    200    400
# 1    3      4      5

# %%
productdf = productdf.drop(columns= ["Mobile"])
productdf
# Out:
#    Pen  Shirt  Book  Mouse
# 0  100    200   300    400
# 1    3      4     2      5

# %% [markdown]
# ##### Drop rows from the data farme
# ##### . Drop(Need to specify that axis = 0 or 'index', axis=1 or 'coloumns)

# %%
#Deleting row from the data frame
df3 = df2.drop(index=[0])
df3
# Out:
#    Pen  Shirt  Mouse
# 1    3      4      5

# %% [markdown]
# ### Combining Dataframes

# %% [markdown]
# ##### Append

# %%
#Create a new dat frame.
productdf2 = pd.DataFrame([[15,16,17,18],[5,6,7,8]],columns=['Pen','Shirt','Book','Mouse'])
productdf2
# Out:
#    Pen  Shirt  Book  Mouse
# 0   15     16    17     18
# 1    5      6     7      8

# %%
#Adding rows to the data frame by adding other data frame.
df5 = productdf.append(productdf2)
df5
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14496\1599175444.py in ?()
#       1 #Adding rows to the data frame by adding other data frame.
# ----> 2 df5 = productdf.append(productdf2)
#       3 df5
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
#Creating a new data frame.
productdf3 = pd.DataFrame([[15,16,17,18],[5,6,7,8]],columns=['Pens','Shirt','Book','Mouse'])
productdf3
# Out:
#    Pens  Shirt  Book  Mouse
# 0    15     16    17     18
# 1     5      6     7      8

# %%
productdf.append(productdf3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20808\785406594.py in ?()
# ----> 1 productdf.append(productdf3)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %% [markdown]
# ### Concatenate

# %%
india_weather = pd.DataFrame({
"city":["mumbai","delhi","banglore"],
"temperature":[32,45,30],
"humidity":[80,60,74]
})

india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        74

# %%
import pandas as pd
us_weather = pd.DataFrame({
"city":["new york","chicago","orlando"],
"temerature":[21,14,35],
"humidity":[68,65,75]
})
us_weather
# Out:
#        city  temerature  humidity
# 0  new york          21        68
# 1   chicago          14        65
# 2   orlando          35        75

# %%
#concate two dataframes

df = pd.concat([india_weather, us_weather])
df
# Out:
#        city  temperature  humidity  temerature
# 0    mumbai         32.0        80         NaN
# 1     delhi         45.0        60         NaN
# 2  banglore         30.0        74         NaN
# 0  new york          NaN        68        21.0
# 1   chicago          NaN        65        14.0
# 2   orlando          NaN        75        35.0

# %%
df = pd.concat([india_weather, us_weather],axis=0)
df
# Out:
#        city  temperature  humidity  temerature
# 0    mumbai         32.0        80         NaN
# 1     delhi         45.0        60         NaN
# 2  banglore         30.0        74         NaN
# 0  new york          NaN        68        21.0
# 1   chicago          NaN        65        14.0
# 2   orlando          NaN        75        35.0

# %% [markdown]
# #### Merging of DataFrame

# %%
temperature_df = pd.DataFrame({
"city":["mubai","delhi","banglore","hyderabad"],
"temperature":[32,45,30,40]})

temperature_df
# Out:
#         city  temperature
# 0      mubai           32
# 1      delhi           45
# 2   banglore           30
# 3  hyderabad           40

# %%
humidity_df = pd.DataFrame({
"city": ["delhi","mumbai","banglore"],
"humidity":[68,65,75]})
humidity_df
# Out:
#        city  humidity
# 0     delhi        68
# 1    mumbai        65
# 2  banglore        75

# %%
# merge two dataframes with out explicitly mention index
df = pd.merge(temperature_df, humidity_df, on='city')
df
# Out:
#        city  temperature  humidity
# 0     delhi           45        68
# 1  banglore           30        75

# %%
# outer-join
df = pd.merge(temperature_df, humidity_df, on='city', how='outer')
df
# Out:
#         city  temperature  humidity
# 0      mubai         32.0       NaN
# 1      delhi         45.0      68.0
# 2   banglore         30.0      75.0
# 3  hyderabad         40.0       NaN
# 4     mumbai          NaN      65.0

# %% [markdown]
# ### import data

# %%
df = pd.read_csv(r"C:\Users\Subrat Jena\Downloads\archive\indianEco.csv")
df.head()
# Out:
#    Year Country Name  GDP (current US$)    GDP per capita (current US$)   \
# 0  1960        India        3.702988e+10                              82
# 1  1961        India        3.923244e+10                              85
# 2  1962        India        4.216148e+10                              90
# 3  1963        India        4.842192e+10                             101
# 4  1964        India        5.648029e+10                             116
#
#    GDP growth (annual %)  Imports of goods and services (% of GDP)  \
# 0                   0.00                                      6.83
# 1                   3.72                                      5.96
# 2                   2.93                                      6.03
# 3                   5.99                                      5.91
# 4                   7.45                                      5.69
#
#    Exports of goods and services (% of GDP)  \
# 0                                      4.46
# ...

# %%
#show the last 5 observations
df.tail()
# Out:
#     Year Country Name  GDP (current US$)    GDP per capita (current US$)   \
# 56  2016        India        2.290000e+12                            1733
# 57  2017        India        2.650000e+12                            1981
# 58  2018        India        2.700000e+12                            1997
# 59  2019        India        2.830000e+12                            2101
# 60  2020        India        2.670000e+12                            1928
#
#     GDP growth (annual %)  Imports of goods and services (% of GDP)  \
# 56                   8.26                                     20.92
# 57                   6.80                                     21.95
# 58                   6.53                                     23.69
# 59                   4.04                                     21.27
# 60                  -7.25                                     19.10
#
#     Exports of goods and services (% of GDP)  \
# 56                                     19.16
# ...

# %%
df.shape
# Out:
# (61, 12)

# %%
df.size
# Out:
# 732

# %%
df.columns
# Out:
# Index(['Year', 'Country Name', 'GDP (current US$) ',
#        ' GDP per capita (current US$) ', 'GDP growth (annual %)',
#        'Imports of goods and services (% of GDP)',
#        'Exports of goods and services (% of GDP)',
#        ' Total reserves (includes gold, current US$) ',
#        'Inflation, consumer prices (annual %)', 'Population, total',
#        'Population growth (annual %)',
#        'Life expectancy at birth, total (years)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Year                                               int64
# Country Name                                      object
# GDP (current US$)                                float64
#  GDP per capita (current US$)                      int64
# GDP growth (annual %)                            float64
# Imports of goods and services (% of GDP)         float64
# Exports of goods and services (% of GDP)         float64
#  Total reserves (includes gold, current US$)     float64
# Inflation, consumer prices (annual %)            float64
# Population, total                                  int64
# Population growth (annual %)                     float64
# Life expectancy at birth, total (years)          float64
# dtype: object

# %%
#Cocise summary of a DataFrame 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Year                                           61 non-null     int64
#  1   Country Name                                   61 non-null     object
#  2   GDP (current US$)                              61 non-null     float64
#  3    GDP per capita (current US$)                  61 non-null     int64
#  4   GDP growth (annual %)                          61 non-null     float64
#  5   Imports of goods and services (% of GDP)       61 non-null     float64
#  6   Exports of goods and services (% of GDP)       61 non-null     float64
#  7    Total reserves (includes gold, current US$)   61 non-null     float64
#  8   Inflation, consumer prices (annual %)          61 non-null     float64
# ...

# %%
#total no.of Missing values in each column
df.isnull().sum()
# Out:
# Year                                             0
# Country Name                                     0
# GDP (current US$)                                0
#  GDP per capita (current US$)                    0
# GDP growth (annual %)                            0
# Imports of goods and services (% of GDP)         0
# Exports of goods and services (% of GDP)         0
#  Total reserves (includes gold, current US$)     0
# Inflation, consumer prices (annual %)            0
# Population, total                                0
# Population growth (annual %)                     0
# Life expectancy at birth, total (years)          0
# dtype: int64

# %%
#Displaying deseriptive statistical values of column using describe()
df.describe()
# Out:
#               Year  GDP (current US$)    GDP per capita (current US$)   \
# count    61.000000        6.100000e+01                       61.000000
# mean   1990.000000        6.583962e+11                      575.557377
# std      17.752934        8.127562e+11                      584.079062
# min    1960.000000        3.702988e+10                       82.000000
# 25%    1975.000000        9.952590e+10                      161.000000
# 50%    1990.000000        2.880000e+11                      340.000000
# 75%    2005.000000        8.200000e+11                      715.000000
# max    2020.000000        2.830000e+12                     2101.000000
#
#        GDP growth (annual %)  Imports of goods and services (% of GDP)  \
# count              61.000000                                 61.000000
# mean                4.938197                                 12.746393
# std                 3.344891                                  8.155110
# ...

# %%
df.describe(include="all")
# Out:
#                Year Country Name  GDP (current US$)   \
# count     61.000000           61        6.100000e+01
# unique          NaN            1                 NaN
# top             NaN        India                 NaN
# freq            NaN           61                 NaN
# mean    1990.000000          NaN        6.583962e+11
# std       17.752934          NaN        8.127562e+11
# min     1960.000000          NaN        3.702988e+10
# 25%     1975.000000          NaN        9.952590e+10
# 50%     1990.000000          NaN        2.880000e+11
# 75%     2005.000000          NaN        8.200000e+11
# max     2020.000000          NaN        2.830000e+12
#
#          GDP per capita (current US$)   GDP growth (annual %)  \
# count                        61.000000              61.000000
# unique                             NaN                    NaN
# top                                NaN                    NaN
# freq                               NaN                    NaN
# ...

# %%
print(df.describe())
# Out:
#               Year  GDP (current US$)    GDP per capita (current US$)   \
# count    61.000000        6.100000e+01                       61.000000
# mean   1990.000000        6.583962e+11                      575.557377
# std      17.752934        8.127562e+11                      584.079062
# min    1960.000000        3.702988e+10                       82.000000
# 25%    1975.000000        9.952590e+10                      161.000000
# 50%    1990.000000        2.880000e+11                      340.000000
# 75%    2005.000000        8.200000e+11                      715.000000
# max    2020.000000        2.830000e+12                     2101.000000
#
#        GDP growth (annual %)  Imports of goods and services (% of GDP)  \
# count              61.000000                                 61.000000
# mean                4.938197                                 12.746393
# std                 3.344891                                  8.155110
# ...

# %% [markdown]
# ### Single Column

# %%
# just get the GDP column and save it to its own variable
df.columns = df.columns.str.strip()  # Clean up column names
gdp_column = df['GDP (current US$)']  # Access the cleaned colum
print(gdp_column)
# Out:
# 0     3.702988e+10
# 1     3.923244e+10
# 2     4.216148e+10
# 3     4.842192e+10
# 4     5.648029e+10
#           ...
# 56    2.290000e+12
# 57    2.650000e+12
# 58    2.700000e+12
# 59    2.830000e+12
# 60    2.670000e+12
# Name: GDP (current US$), Length: 61, dtype: float64

# %% [markdown]
# ### Multiple Columns

# %%
df[['GDP (current US$)','GDP growth (annual %)']]
# Out:
#     GDP (current US$)  GDP growth (annual %)
# 0        3.702988e+10                   0.00
# 1        3.923244e+10                   3.72
# 2        4.216148e+10                   2.93
# 3        4.842192e+10                   5.99
# 4        5.648029e+10                   7.45
# ..                ...                    ...
# 56       2.290000e+12                   8.26
# 57       2.650000e+12                   6.80
# 58       2.700000e+12                   6.53
# 59       2.830000e+12                   4.04
# 60       2.670000e+12                  -7.25
#
# [61 rows x 2 columns]

# %%
#Determine all the values of column only.
df['Population growth (annual %)'].values
# Out:
# array([2.31, 2.33, 2.34, 2.34, 2.33, 2.26, 2.18, 2.15, 2.19, 2.23, 2.23,
#        2.24, 2.25, 2.28, 2.28, 2.26, 2.23, 2.23, 2.24, 2.25, 2.29, 2.3 ,
#        2.29, 2.28, 2.29, 2.27, 2.26, 2.24, 2.21, 2.19, 2.16, 2.12, 2.1 ,
#        2.07, 2.04, 2.01, 1.97, 1.94, 1.91, 1.87, 1.84, 1.82, 1.79, 1.74,
#        1.69, 1.62, 1.54, 1.48, 1.43, 1.4 , 1.39, 1.37, 1.34, 1.31, 1.25,
#        1.19, 1.19, 1.16, 1.09, 1.03, 0.96])

# %%
df
# Out:
#     Year Country Name  GDP (current US$)  GDP per capita (current US$)  \
# 0   1960        India       3.702988e+10                            82
# 1   1961        India       3.923244e+10                            85
# 2   1962        India       4.216148e+10                            90
# 3   1963        India       4.842192e+10                           101
# 4   1964        India       5.648029e+10                           116
# ..   ...          ...                ...                           ...
# 56  2016        India       2.290000e+12                          1733
# 57  2017        India       2.650000e+12                          1981
# 58  2018        India       2.700000e+12                          1997
# 59  2019        India       2.830000e+12                          2101
# 60  2020        India       2.670000e+12                          1928
#
#     GDP growth (annual %)  Imports of goods and services (% of GDP)  \
# ...

# %% [markdown]
# ### Create a new Column

# %%
df["m"] = df["GDP (current US$)"]/2
df
# Out:
#     Year Country Name  GDP (current US$)  GDP per capita (current US$)  \
# 0   1960        India       3.702988e+10                            82
# 1   1961        India       3.923244e+10                            85
# 2   1962        India       4.216148e+10                            90
# 3   1963        India       4.842192e+10                           101
# 4   1964        India       5.648029e+10                           116
# ..   ...          ...                ...                           ...
# 56  2016        India       2.290000e+12                          1733
# 57  2017        India       2.650000e+12                          1981
# 58  2018        India       2.700000e+12                          1997
# 59  2019        India       2.830000e+12                          2101
# 60  2020        India       2.670000e+12                          1928
#
#     GDP growth (annual %)  Imports of goods and services (% of GDP)  \
# ...

# %%
df.drop("m",axis=1,inplace=True)
df
# Out:
#     Year Country Name  GDP (current US$)  GDP per capita (current US$)  \
# 0   1960        India       3.702988e+10                            82
# 1   1961        India       3.923244e+10                            85
# 2   1962        India       4.216148e+10                            90
# 3   1963        India       4.842192e+10                           101
# 4   1964        India       5.648029e+10                           116
# ..   ...          ...                ...                           ...
# 56  2016        India       2.290000e+12                          1733
# 57  2017        India       2.650000e+12                          1981
# 58  2018        India       2.700000e+12                          1997
# 59  2019        India       2.830000e+12                          2101
# 60  2020        India       2.670000e+12                          1928
#
#     GDP growth (annual %)  Imports of goods and services (% of GDP)  \
# ...

# %% [markdown]
# ### Selecting paricular rows & columns
# #### iloc

# %%
#get the first row
df.iloc[0]
# Out:
# Year                                                    1960
# Country Name                                           India
# GDP (current US$)                              37029883876.0
# GDP per capita (current US$)                              82
# GDP growth (annual %)                                    0.0
# Imports of goods and services (% of GDP)                6.83
# Exports of goods and services (% of GDP)                4.46
# Total reserves (includes gold, current US$)      674536630.9
# Inflation, consumer prices (annual %)                   1.78
# Population, total                                  445954579
# Population growth (annual %)                            2.31
# Life expectancy at birth, total (years)                41.13
# m                                              18514941938.0
# Name: 0, dtype: object

# %%
#get the 60th row
df.iloc[59]
# Out:
# Year                                                      2019
# Country Name                                             India
# GDP (current US$)                              2830000000000.0
# GDP per capita (current US$)                              2101
# GDP growth (annual %)                                     4.04
# Imports of goods and services (% of GDP)                 21.27
# Exports of goods and services (% of GDP)                 18.69
# Total reserves (includes gold, current US$)     463000000000.0
# Inflation, consumer prices (annual %)                     3.73
# Population, total                                   1383112050
# Population growth (annual %)                              1.03
# Life expectancy at birth, total (years)                   69.5
# m                                              1415000000000.0
# Name: 59, dtype: object

# %%
df.iloc[[0,45,57]]
# Out:
#     Year Country Name  GDP (current US$)  GDP per capita (current US$)  \
# 0   1960        India       3.702988e+10                            82
# 45  2005        India       8.200000e+11                           715
# 57  2017        India       2.650000e+12                          1981
#
#     GDP growth (annual %)  Imports of goods and services (% of GDP)  \
# 0                    0.00                                      6.83
# 45                   7.92                                     22.40
# 57                   6.80                                     21.95
#
#     Exports of goods and services (% of GDP)  \
# 0                                       4.46
# 45                                     19.61
# 57                                     18.79
#
#     Total reserves (includes gold, current US$)  \
# 0                                  6.745366e+08
# 45                                 1.380000e+11
# 57                                 4.130000e+11
#
# ...

# %%
# Select the 4th row and 3rd column
df.iloc[3,2]
# Out:
# 48421923459.0

# %%
#Displaying multiple specified columns and rows.
df.iloc[[5,7],[1,5]]
# Out:
#   Country Name  Imports of goods and services (% of GDP)
# 5        India                                      5.21
# 7        India                                      5.95

# %%
#Displaying specific column of range of rows.
df.iloc[7:15,[6]]
# Out:
#     Exports of goods and services (% of GDP)
# 7                                       4.03
# 8                                       4.04
# 9                                       3.71
# 10                                      3.78
# 11                                      3.67
# 12                                      4.03
# 13                                      4.21
# 14                                      4.83

# %%
# get the first row 
print(df.loc[0])
# Out:
# Year                                                    1960
# Country Name                                           India
# GDP (current US$)                              37029883876.0
# GDP per capita (current US$)                              82
# GDP growth (annual %)                                    0.0
# Imports of goods and services (% of GDP)                6.83
# Exports of goods and services (% of GDP)                4.46
# Total reserves (includes gold, current US$)      674536630.9
# Inflation, consumer prices (annual %)                   1.78
# Population, total                                  445954579
# Population growth (annual %)                            2.31
# Life expectancy at birth, total (years)                41.13
# m                                              18514941938.0
# Name: 0, dtype: object

# %%
#recall the values start with 0
print(df.loc[59])
# Out:
# Year                                                      2019
# Country Name                                             India
# GDP (current US$)                              2830000000000.0
# GDP per capita (current US$)                              2101
# GDP growth (annual %)                                     4.04
# Imports of goods and services (% of GDP)                 21.27
# Exports of goods and services (% of GDP)                 18.69
# Total reserves (includes gold, current US$)     463000000000.0
# Inflation, consumer prices (annual %)                     3.73
# Population, total                                   1383112050
# Population growth (annual %)                              1.03
# Life expectancy at birth, total (years)                   69.5
# m                                              1415000000000.0
# Name: 59, dtype: object

# %%
#get the last row
print(df.loc[-1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:414, in RangeIndex.get_loc(self, key)
#     413 try:
# --> 414     return self._range.index(new_key)
#     415 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 2
#       1 #get the last row
# ----> 2 print(df.loc[-1])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
df.tail()
# Out:
#     Year Country Name  GDP (current US$)  GDP per capita (current US$)  \
# 56  2016        India       2.290000e+12                          1733
# 57  2017        India       2.650000e+12                          1981
# 58  2018        India       2.700000e+12                          1997
# 59  2019        India       2.830000e+12                          2101
# 60  2020        India       2.670000e+12                          1928
#
#     GDP growth (annual %)  Imports of goods and services (% of GDP)  \
# 56                   8.26                                     20.92
# 57                   6.80                                     21.95
# 58                   6.53                                     23.69
# 59                   4.04                                     21.27
# 60                  -7.25                                     19.10
#
#     Exports of goods and services (% of GDP)  \
# 56                                     19.16
# ...

# %%
df.loc[43]
# Out:
# Year                                                     2003
# Country Name                                            India
# GDP (current US$)                              608000000000.0
# GDP per capita (current US$)                              547
# GDP growth (annual %)                                    7.86
# Imports of goods and services (% of GDP)                15.64
# Exports of goods and services (% of GDP)                14.95
# Total reserves (includes gold, current US$)    104000000000.0
# Inflation, consumer prices (annual %)                    3.81
# Population, total                                  1117415123
# Population growth (annual %)                             1.74
# Life expectancy at birth, total (years)                  63.5
# m                                              304000000000.0
# Name: 43, dtype: object

# %%
df.loc[2:5,]
# Out:
#    Year Country Name  GDP (current US$)  GDP per capita (current US$)  \
# 2  1962        India       4.216148e+10                            90
# 3  1963        India       4.842192e+10                           101
# 4  1964        India       5.648029e+10                           116
# 5  1965        India       5.955485e+10                           119
#
#    GDP growth (annual %)  Imports of goods and services (% of GDP)  \
# 2                   2.93                                      6.03
# 3                   5.99                                      5.91
# 4                   7.45                                      5.69
# 5                  -2.64                                      5.21
#
#    Exports of goods and services (% of GDP)  \
# 2                                      4.17
# 3                                      4.28
# 4                                      3.73
# 5                                      3.31
#
# ...

# %%
#Retrieving selected rows with range of columns between 'GDP (current US$)' and 'GDP growth (annual %)
df.loc[[3,4],'GDP (current US$)':'GDP growth (annual %)']
# Out:
#    GDP (current US$)  GDP per capita (current US$)  GDP growth (annual %)
# 3       4.842192e+10                           101                   5.99
# 4       5.648029e+10                           116                   7.45

# %% [markdown]
# #### just make sure you don't confuse the differences between loc and iloc

# %%
df.loc[22,'GDP (current US$)']
# Out:
# 201000000000.0

# %%
df.iloc[22,0]
# Out:
# 1982

# %%
df.iloc[0,0]
# Out:
# 1960

# %%
df.iloc[[0,9,49],[0,3,6]]
# Out:
#     Year  GDP per capita (current US$)  \
# 0   1960                            82
# 9   1969                           108
# 49  2009                          1102
#
#     Exports of goods and services (% of GDP)
# 0                                       4.46
# 9                                       3.71
# 49                                     20.40

# %% [markdown]
# ### SetIndex

# %%
l1 = df.set_index("Year")
l1.head()
# Out:
#      Country Name  GDP (current US$)  GDP per capita (current US$)  \
# Year
# 1960        India       3.702988e+10                            82
# 1961        India       3.923244e+10                            85
# 1962        India       4.216148e+10                            90
# 1963        India       4.842192e+10                           101
# 1964        India       5.648029e+10                           116
#
#       GDP growth (annual %)  Imports of goods and services (% of GDP)  \
# Year
# 1960                   0.00                                      6.83
# 1961                   3.72                                      5.96
# 1962                   2.93                                      6.03
# 1963                   5.99                                      5.91
# 1964                   7.45                                      5.69
#
#       Exports of goods and services (% of GDP)  \
# Year
# 1960                                      4.46
# ...

# %%
l1.shape
# Out:
# (61, 12)

# %%
l1.loc[2020]
# Out:
# Country Name                                             India
# GDP (current US$)                              2670000000000.0
# GDP per capita (current US$)                              1928
# GDP growth (annual %)                                    -7.25
# Imports of goods and services (% of GDP)                  19.1
# Exports of goods and services (% of GDP)                 18.71
# Total reserves (includes gold, current US$)     590000000000.0
# Inflation, consumer prices (annual %)                     6.62
# Population, total                                   1396387127
# Population growth (annual %)                              0.96
# Life expectancy at birth, total (years)                  69.73
# m                                              1335000000000.0
# Name: 2020, dtype: object

# %%
l1.loc[2020,'GDP (current US$)':'GDP growth (annual %)']
# Out:
# GDP (current US$)               2670000000000.0
# GDP per capita (current US$)               1928
# GDP growth (annual %)                     -7.25
# Name: 2020, dtype: object

# %%
l1.reset_index()
# Out:
#     Year Country Name  GDP (current US$)  GDP per capita (current US$)  \
# 0   1960        India       3.702988e+10                            82
# 1   1961        India       3.923244e+10                            85
# 2   1962        India       4.216148e+10                            90
# 3   1963        India       4.842192e+10                           101
# 4   1964        India       5.648029e+10                           116
# ..   ...          ...                ...                           ...
# 56  2016        India       2.290000e+12                          1733
# 57  2017        India       2.650000e+12                          1981
# 58  2018        India       2.700000e+12                          1997
# 59  2019        India       2.830000e+12                          2101
# 60  2020        India       2.670000e+12                          1928
#
#     GDP growth (annual %)  Imports of goods and services (% of GDP)  \
# ...

# %%
#Determine number of records of each category in column
df['GDP (current US$)'].value_counts()
# Out:
# GDP (current US$)
# 2.790000e+11    2
# 3.702988e+10    1
# 2.700000e+11    1
# 3.270000e+11    1
# 3.600000e+11    1
# 3.930000e+11    1
# 4.160000e+11    1
# 4.210000e+11    1
# 4.590000e+11    1
# 4.680000e+11    1
# 4.850000e+11    1
# 5.150000e+11    1
# 6.080000e+11    1
# 7.090000e+11    1
# 8.200000e+11    1
# 9.400000e+11    1
# 1.220000e+12    1
# 1.200000e+12    1
# 1.340000e+12    1
# 1.680000e+12    1
# 1.820000e+12    1
# 1.830000e+12    1
# 1.860000e+12    1
# 2.040000e+12    1
# 2.100000e+12    1
# 2.290000e+12    1
# 2.650000e+12    1
# 2.700000e+12    1
# 2.830000e+12    1
# 2.880000e+11    1
# 3.210000e+11    1
# 3.923244e+10    1
# 9.952590e+10    1
# 4.216148e+10    1
# 4.842192e+10    1
# 5.648029e+10    1
# 5.955485e+10    1
# 4.586546e+10    1
# 5.013494e+10    1
# 5.308546e+10    1
# 5.844800e+10    1
# 6.242248e+10    1
# 6.735099e+10    1
# 7.146319e+10    1
# 8.551527e+10    1
# 9.847280e+10    1
# 2.960000e+11    1
# 1.030000e+11    1
# 1.210000e+11    1
# ...

# %%
#Determine number of records based on year in percentage form.
df['GDP (current US$)'].value_counts()/len(df['GDP (current US$)'])
# Out:
# GDP (current US$)
# 2.790000e+11    0.032787
# 3.702988e+10    0.016393
# 2.700000e+11    0.016393
# 3.270000e+11    0.016393
# 3.600000e+11    0.016393
# 3.930000e+11    0.016393
# 4.160000e+11    0.016393
# 4.210000e+11    0.016393
# 4.590000e+11    0.016393
# 4.680000e+11    0.016393
# 4.850000e+11    0.016393
# 5.150000e+11    0.016393
# 6.080000e+11    0.016393
# 7.090000e+11    0.016393
# 8.200000e+11    0.016393
# 9.400000e+11    0.016393
# 1.220000e+12    0.016393
# 1.200000e+12    0.016393
# 1.340000e+12    0.016393
# 1.680000e+12    0.016393
# 1.820000e+12    0.016393
# 1.830000e+12    0.016393
# 1.860000e+12    0.016393
# 2.040000e+12    0.016393
# 2.100000e+12    0.016393
# 2.290000e+12    0.016393
# 2.650000e+12    0.016393
# 2.700000e+12    0.016393
# 2.830000e+12    0.016393
# 2.880000e+11    0.016393
# 3.210000e+11    0.016393
# 3.923244e+10    0.016393
# 9.952590e+10    0.016393
# 4.216148e+10    0.016393
# 4.842192e+10    0.016393
# 5.648029e+10    0.016393
# ...

# %%
#Determine number of records based on gdp in percentage form.
df['GDP (current US$)'].value_counts(normalize=True)
# Out:
# GDP (current US$)
# 2.790000e+11    0.032787
# 3.702988e+10    0.016393
# 2.700000e+11    0.016393
# 3.270000e+11    0.016393
# 3.600000e+11    0.016393
# 3.930000e+11    0.016393
# 4.160000e+11    0.016393
# 4.210000e+11    0.016393
# 4.590000e+11    0.016393
# 4.680000e+11    0.016393
# 4.850000e+11    0.016393
# 5.150000e+11    0.016393
# 6.080000e+11    0.016393
# 7.090000e+11    0.016393
# 8.200000e+11    0.016393
# 9.400000e+11    0.016393
# 1.220000e+12    0.016393
# 1.200000e+12    0.016393
# 1.340000e+12    0.016393
# 1.680000e+12    0.016393
# 1.820000e+12    0.016393
# 1.830000e+12    0.016393
# 1.860000e+12    0.016393
# 2.040000e+12    0.016393
# 2.100000e+12    0.016393
# 2.290000e+12    0.016393
# 2.650000e+12    0.016393
# 2.700000e+12    0.016393
# 2.830000e+12    0.016393
# 2.880000e+11    0.016393
# 3.210000e+11    0.016393
# 3.923244e+10    0.016393
# 9.952590e+10    0.016393
# 4.216148e+10    0.016393
# 4.842192e+10    0.016393
# 5.648029e+10    0.016393
# ...

# %%
df['GDP (current US$)'].mean()
# Out:
# 658396153355.4918

# %%
df['GDP (current US$)'].median()
# Out:
# 288000000000.0

# %%
df['GDP (current US$)'].max()
# Out:
# 2830000000000.0

# %%
df['GDP (current US$)'].min()
# Out:
# 37029883876.0

# %%
df['GDP (current US$)'].sum()
# Out:
# 40162165354685.0

# %%
df['GDP (current US$)'].product()
# Out:
# C:\Users\Subrat Jena\anaconda3\Lib\site-packages\numpy\core\_methods.py:53: RuntimeWarning: overflow encountered in reduce
#   return umr_prod(a, axis, dtype, out, keepdims, initial, where)
# inf

# %%
df['GDP (current US$)'].nsmallest()
# Out:
# 0    3.702988e+10
# 1    3.923244e+10
# 2    4.216148e+10
# 6    4.586546e+10
# 3    4.842192e+10
# Name: GDP (current US$), dtype: float64

# %%
df['GDP (current US$)'].nlargest()
# Out:
# 59    2.830000e+12
# 58    2.700000e+12
# 60    2.670000e+12
# 57    2.650000e+12
# 56    2.290000e+12
# Name: GDP (current US$), dtype: float64

# %% [markdown]
# ### Sort Functions

# %%
# sorting in descending order.
df.sort_values(by='GDP (current US$)',ascending=False)
# Out:
#     Year Country Name  GDP (current US$)  GDP per capita (current US$)  \
# 59  2019        India       2.830000e+12                          2101
# 58  2018        India       2.700000e+12                          1997
# 60  2020        India       2.670000e+12                          1928
# 57  2017        India       2.650000e+12                          1981
# 56  2016        India       2.290000e+12                          1733
# ..   ...          ...                ...                           ...
# 3   1963        India       4.842192e+10                           101
# 6   1966        India       4.586546e+10                            90
# 2   1962        India       4.216148e+10                            90
# 1   1961        India       3.923244e+10                            85
# 0   1960        India       3.702988e+10                            82
#
#     GDP growth (annual %)  Imports of goods and services (% of GDP)  \
# ...

# %%
#sorting in ascending order.
df.sort_values(by='GDP (current US$)',ascending=True)
# Out:
#     Year Country Name  GDP (current US$)  GDP per capita (current US$)  \
# 0   1960        India       3.702988e+10                            82
# 1   1961        India       3.923244e+10                            85
# 2   1962        India       4.216148e+10                            90
# 6   1966        India       4.586546e+10                            90
# 3   1963        India       4.842192e+10                           101
# ..   ...          ...                ...                           ...
# 56  2016        India       2.290000e+12                          1733
# 57  2017        India       2.650000e+12                          1981
# 60  2020        India       2.670000e+12                          1928
# 58  2018        India       2.700000e+12                          1997
# 59  2019        India       2.830000e+12                          2101
#
#     GDP growth (annual %)  Imports of goods and services (% of GDP)  \
# ...

# %% [markdown]
# ### Data Extraction

# %%
#Displaying the records where gender is male.
year_data=df[df['GDP (current US$)']=='2020']
year_data
# Out:
# Empty DataFrame
# Columns: [Year, Country Name, GDP (current US$), GDP per capita (current US$), GDP growth (annual %), Imports of goods and services (% of GDP), Exports of goods and services (% of GDP), Total reserves (includes gold, current US$), Inflation, consumer prices (annual %), Population, total, Population growth (annual %), Life expectancy at birth, total (years), m]
# Index: []
